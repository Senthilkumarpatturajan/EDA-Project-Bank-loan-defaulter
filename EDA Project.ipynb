# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
loan_data=pd.read_csv(r'C:\Users\Senthilkumar P\Downloads\Python_Lecture_203252-20240223T035927Z-001\Python_Lecture_203252\EDA\Bank_Loan_Defaulter.csv')

# %%
loan_data.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED MOBILE  \
# 0          202500.0    406597.5         351000.0  ...          -637      1
# 1          270000.0   1293502.5        1129500.0  ...         -1188      1
# 2           67500.0    135000.0         135000.0  ...          -225      1
# 3          135000.0    312682.5         297000.0  ...         -3039      1
# 4          121500.0    513000.0         513000.0  ...         -3038      1
#
#   WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  OCCUPATION_TYPE  \
# ...

# %% [raw]
# Data Dictionary
# -----------------------
# SK_ID_CURR: Unique identifier for each individual in the dataset.
# TARGET: Binary variable indicating whether the individual had difficulty repaying a loan (1) or not (0).
# NAME_CONTRACT_TYPE: Type of loan contract, such as "Cash loans" or "Revolving loans".
# GENDER: Gender of the individual.
# Car: Binary variable indicating whether the individual owns a car (1) or not (0).
# House: Binary variable indicating whether the individual owns a house (1) or not (0).
# CNT_CHILDREN: Number of children the individual has.
# AMT_INCOME_TOTAL: Total annual income of the individual.
# AMT_CREDIT: Total credit amount of the loan.
# AMT_GOODS_PRICE: Price of the goods for which the loan is given.
# NAME_TYPE_SUITE: Who was accompanying the individual when applying for the loan.
# NAME_INCOME_TYPE: Type of income the individual receives (e.g., "Working", "Pensioner").
# NAME_EDUCATION_TYPE: Highest level of education the individual has completed.
# NAME_FAMILY_STATUS: Family status of the individual (e.g., "Married", "Single").
# DAYS_EMPLOYED: Number of days the individual has been employed (could be negative).
# MOBILE, WORK_PHONE, HOME_PHONE: Binary variables indicating the presence of a mobile, work phone, and home phone, respectively.
# MOBILE_REACHABLE: Binary variable indicating whether the individual can be reached by mobile phone (1) or not (0).
# FLAG_EMAIL: Binary variable indicating whether the individual has an email address (1) or not (0).
# OCCUPATION_TYPE: Type of occupation of the individual.
# CNT_FAM_MEMBERS: Number of family members.
# APPLICATION_DAY: Day of the month when the loan application was submitted.
# TOTAL_DOC_SUBMITTED: Total number of documents submitted with the loan application.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')

# %%
loan_data.shape
# Out:
# (100000, 24)

# %% [raw]
# L0:
# 1.Visually inspect the first few and last few rows of the data
# 2.Check the shape of the data frame
# 3.Check the count of null values in each column
# 4.Inspect all the column names and cross check with the data dictionary
# 5.Check the information of the data frame using the info() function

# %% [markdown]
# # Visually inspect the first few and last few rows of the data

# %%
loan_data.head(5)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED MOBILE  \
# 0          202500.0    406597.5         351000.0  ...          -637      1
# 1          270000.0   1293502.5        1129500.0  ...         -1188      1
# 2           67500.0    135000.0         135000.0  ...          -225      1
# 3          135000.0    312682.5         297000.0  ...         -3039      1
# 4          121500.0    513000.0         513000.0  ...         -3038      1
#
#   WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  OCCUPATION_TYPE  \
# ...

# %%
loan_data.tail(5)
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
#        AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED  \
# 99995          157500.0    755190.0         675000.0  ...          -232
# 99996          225000.0    284400.0         225000.0  ...          -182
# 99997          135000.0   1262583.0        1102500.0  ...         -4805
# 99998          135000.0    225000.0         225000.0  ...          -340
# 99999          202500.0    337500.0         337500.0  ...         -3230
#
#       MOBILE WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  \
# ...

# %% [markdown]
# # info about null value,nos rows and columns with datatypes

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SK_ID_CURR           100000 non-null  int64
#  1   TARGET               100000 non-null  int64
#  2   NAME_CONTRACT_TYPE   100000 non-null  object
#  3   GENDER               100000 non-null  object
#  4   Car                  100000 non-null  object
#  5   House                100000 non-null  object
#  6   CNT_CHILDREN         100000 non-null  int64
#  7   AMT_INCOME_TOTAL     100000 non-null  float64
#  8   AMT_CREDIT           100000 non-null  float64
#  9   AMT_GOODS_PRICE      99919 non-null   float64
#  10  NAME_TYPE_SUITE      99595 non-null   object
#  11  NAME_INCOME_TYPE     100000 non-null  object
#  12  NAME_EDUCATION_TYPE  100000 non-null  object
#  13  NAME_FAMILY_STATUS   100000 non-null  object
#  14  DAYS_EMPLOYED        100000 non-null  int64
# ...

# %% [markdown]
# # Null value treatment

# %%
loan_data.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE           81
# NAME_TYPE_SUITE          405
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %%
loan_data['CNT_FAM_MEMBERS'].fillna(loan_data['CNT_FAM_MEMBERS'].mode()[0],inplace=True)

# %%
loan_data['NAME_TYPE_SUITE'].fillna(loan_data['NAME_TYPE_SUITE'].mode()[0],inplace=True)

# %% [markdown]
# # Datatypes

# %%
loan_data.dtypes
# Out:
# SK_ID_CURR               int64
# TARGET                   int64
# NAME_CONTRACT_TYPE      object
# GENDER                  object
# Car                     object
# House                   object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# AMT_CREDIT             float64
# AMT_GOODS_PRICE        float64
# NAME_TYPE_SUITE         object
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# DAYS_EMPLOYED            int64
# MOBILE                   int64
# WORK_PHONE               int64
# HOME_PHONE               int64
# MOBILE_REACHABLE         int64
# FLAG_EMAIL               int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# APPLICATION_DAY         object
# TOTAL_DOC_SUBMITTED      int64
# dtype: object

# %% [markdown]
# # statistical analysis of Num values

# %%
loan_data.describe().T
# Out:
#                         count           mean            std       min  \
# SK_ID_CURR           100000.0  158006.140860   33481.166996  100002.0
# TARGET               100000.0       0.080930       0.272729       0.0
# CNT_CHILDREN         100000.0       0.417390       0.721014       0.0
# AMT_INCOME_TOTAL     100000.0  169426.070273  383500.744277   25650.0
# AMT_CREDIT           100000.0  599003.446500  402051.959121   45000.0
# AMT_GOODS_PRICE       99919.0  538345.148971  369397.724642   45000.0
# DAYS_EMPLOYED        100000.0   63292.222060  140839.697296  -17531.0
# MOBILE               100000.0       0.999990       0.003162       0.0
# WORK_PHONE           100000.0       0.821280       0.383120       0.0
# HOME_PHONE           100000.0       0.199740       0.399807       0.0
# MOBILE_REACHABLE     100000.0       0.997990       0.044788       0.0
# FLAG_EMAIL           100000.0       0.056190       0.230289       0.0
# ...

# %%
LEVEL 1 Analysis 
Identify the type of data in each column (categorical or numerical)?

Seperate out the categorical columns from the numerical types
 thaFollowing are the kinds of analysist can be performed on categorical data:
Check if the variable is Nominal or Ordinal.
Check how many categories are present in a variable.
Check the Mode of a variable.
Check for Missing values of a variable.
Think how the missing values could be treated.
What kind of graph/chart can be plotted using this data.
Note: We are analyzing only one column at a time (a.k.a. Univariate Analysis
# Out:
#   Cell In[14], line 1
#     LEVEL 1 Analysis
#           ^
# SyntaxError: invalid syntax

# %%
cat=[]
num=[]
def data_type(df):
    for col in df.columns:
        if df[col].nunique()<=15:
            cat.append(col)
        else:
            num.append(col)

data_type(loan_data)

# %%
def mode_cat(cat):
    for col in cat:
        print(f'{col},Mode={loan_data[col].mode()[0]},Nunique {loan_data[col].nunique()} , Missing_Val {loan_data[col].isnull().sum()}')
        
mode_cat(cat)
# Out:
# TARGET,Mode=0,Nunique 2 , Missing_Val 0
# NAME_CONTRACT_TYPE,Mode=Cash loans,Nunique 2 , Missing_Val 0
# GENDER,Mode=F,Nunique 3 , Missing_Val 0
# Car,Mode=N,Nunique 2 , Missing_Val 0
# House,Mode=Y,Nunique 2 , Missing_Val 0
# CNT_CHILDREN,Mode=0,Nunique 12 , Missing_Val 0
# NAME_TYPE_SUITE,Mode=Unaccompanied,Nunique 7 , Missing_Val 0
# NAME_INCOME_TYPE,Mode=Working,Nunique 8 , Missing_Val 0
# NAME_EDUCATION_TYPE,Mode=Secondary / secondary special,Nunique 5 , Missing_Val 0
# NAME_FAMILY_STATUS,Mode=Married,Nunique 6 , Missing_Val 0
# MOBILE,Mode=1,Nunique 2 , Missing_Val 0
# WORK_PHONE,Mode=1,Nunique 2 , Missing_Val 0
# HOME_PHONE,Mode=0,Nunique 2 , Missing_Val 0
# MOBILE_REACHABLE,Mode=1,Nunique 2 , Missing_Val 0
# FLAG_EMAIL,Mode=0,Nunique 2 , Missing_Val 0
# CNT_FAM_MEMBERS,Mode=2.0,Nunique 12 , Missing_Val 0
# APPLICATION_DAY,Mode=TUESDAY,Nunique 7 , Missing_Val 0
# TOTAL_DOC_SUBMITTED,Mode=1,Nunique 5 , Missing_Val 0

# %%
cat/num
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 cat/num
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %% [raw]
# Cat Column Analysis

# %%
cat

# %%
sns.countplot(x=loan_data['TARGET'])

# %%
plt.pie(x=loan_data['TARGET'].value_counts().values,labels=loan_data['TARGET'].value_counts().index,autopct='%.2f%%')
plt.show()

# %%
fig,ax=plt.subplots(ncols=2,nrows=1,figsize=(10,7))
sns.countplot(x=loan_data['TARGET'],ax=ax[0])
plt.pie(x=loan_data['TARGET'].value_counts().values,labels=loan_data['TARGET'].value_counts().index,autopct='%.2f%%')
plt.show()

# %%
ind=loan_data[loan_data['GENDER']=='XNA'].index
loan_data.loc[ind,'GENDER']=loan_data['GENDER'].mode()[0]

# %%
fig,ax=plt.subplots(ncols=2,nrows=1,figsize=(10,6))
sns.countplot(x=loan_data['GENDER'],ax=ax[0])
plt.pie(x=loan_data['GENDER'].value_counts().values,labels=loan_data['GENDER'].value_counts().index,autopct='%.2f%%')
plt.show()

# %%
fig,ax=plt.subplots(ncols=2,nrows=1,figsize=(10,7))
sns.countplot(x=loan_data['NAME_CONTRACT_TYPE'],ax=ax[0])
plt.pie(x=loan_data['NAME_CONTRACT_TYPE'].value_counts().values,labels=loan_data['NAME_CONTRACT_TYPE'].value_counts().index,autopct='%.2f%%')
plt.show()

# %%
loan_data.columns

# %%
fig,ax=plt.subplots(ncols=2,nrows=1,figsize=(10,7))
sns.countplot(x=loan_data['Car'],ax=ax[0])
plt.pie(x=loan_data['Car'].value_counts().values,labels=loan_data['Car'].value_counts().index,autopct='%.2f%%')
plt.show()

# %%
fig,ax=plt.subplots(ncols=2,nrows=1,figsize=(10,7))
sns.countplot(x=loan_data['House'],ax=ax[0])
plt.pie(x=loan_data['House'].value_counts().values,labels=loan_data['House'].value_counts().index,autopct='%.2f%%')
plt.show()

# %%
fig,ax=plt.subplots(ncols=2,nrows=1,figsize=(10,7))
sns.countplot(x=loan_data['CNT_CHILDREN'],ax=ax[0])
plt.pie(x=loan_data['CNT_CHILDREN'].value_counts().values,labels=loan_data['CNT_CHILDREN'].value_counts().index,autopct='%.2f%%')
plt.show()

# %%
fig,ax=plt.subplots(ncols=2,nrows=1,figsize=(10,7))
sns.histplot(x=loan_data['AMT_INCOME_TOTAL'],ax=ax[0])
#sns.boxplot(x=loan_data['AMT_INCOME_TOTAL'].value_counts().values,labels=loan_data['AMT_INCOME_TOTAL'].value_counts().index,autopct='%.2f%%')
plt.show()

# %%
num
# Out:
# ['SK_ID_CURR',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_GOODS_PRICE',
#  'DAYS_EMPLOYED',
#  'OCCUPATION_TYPE']

# %%
plt.boxplot(x=loan_data['AMT_INCOME_TOTAL'])
plt.show()

# %%
plt.hist(x=loan_data['AMT_GOODS_PRICE'])
plt.show()

# %%
EDA:
    L0:
        use basics of pandas head,tail,info,desc,isnull,duplicate
    L1: (univariate EDA) Select one column analysing the data
        cat:countplot,bar,pie
        num:hist,boxplot
    L2: (Bivariate EDA) select two columns and analysing
        cat vs cat:countplot,bar,pie
        cat vs num:lineplot,hist
        num vs num:scatter,barplot
    L3:(Multivariate)select more than two columns and analysing
        heatmap,corr,scatter,pairplot
# Out:
#   Cell In[27], line 1
#     EDA:
#         ^
# SyntaxError: invalid syntax

# %%
cat
# Out:
# ['TARGET',
#  'NAME_CONTRACT_TYPE',
#  'GENDER',
#  'Car',
#  'House',
#  'CNT_CHILDREN',
#  'NAME_TYPE_SUITE',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'MOBILE',
#  'WORK_PHONE',
#  'HOME_PHONE',
#  'MOBILE_REACHABLE',
#  'FLAG_EMAIL',
#  'CNT_FAM_MEMBERS',
#  'APPLICATION_DAY',
#  'TOTAL_DOC_SUBMITTED']

# %%
sns.countplot(x=loan_data['NAME_FAMILY_STATUS'])
# Out:
# <Axes: xlabel='NAME_FAMILY_STATUS', ylabel='count'>

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x=loan_data['NAME_EDUCATION_TYPE'])
#plt.xticks(rotation=45)
# Out:
# <Axes: xlabel='NAME_EDUCATION_TYPE', ylabel='count'>

# %%
num
# Out:
# ['SK_ID_CURR',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_GOODS_PRICE',
#  'DAYS_EMPLOYED',
#  'OCCUPATION_TYPE']

# %%
sns.histplot(x=loan_data['AMT_GOODS_PRICE'])
# Out:
# <Axes: xlabel='AMT_GOODS_PRICE', ylabel='Count'>

# %%
sns.boxplot(x=loan_data['AMT_GOODS_PRICE'])
# Out:
# <Axes: xlabel='AMT_GOODS_PRICE'>

# %%
num cat
num num
# Out:
#   Cell In[34], line 1
#     num cat
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # cat vs cat

# %%
sns.countplot(x=loan_data['TARGET'],hue=loan_data['GENDER'])
# Out:
# <Axes: xlabel='TARGET', ylabel='count'>

# %%
sns.countplot(x=loan_data['TARGET'],hue=loan_data['NAME_EDUCATION_TYPE'])
# Out:
# <Axes: xlabel='TARGET', ylabel='count'>

# %%
sns.countplot(x=loan_data['NAME_FAMILY_STATUS'],hue=loan_data['TARGET'])
plt.xticks(rotation=60)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Single / not married'),
#   Text(1, 0, 'Married'),
#   Text(2, 0, 'Civil marriage'),
#   Text(3, 0, 'Widow'),
#   Text(4, 0, 'Separated'),
#   Text(5, 0, 'Unknown')])

# %% [markdown]
# # Num Vs Num

# %%
cor=round(loan_data['AMT_CREDIT'].corr(loan_data['AMT_GOODS_PRICE']),2)
print(cor)
sns.scatterplot(x=loan_data['AMT_CREDIT'] ,y=loan_data['AMT_GOODS_PRICE'],hue=loan_data['TARGET'],legend=cor)
# Out:
# 0.99
# <Axes: xlabel='AMT_CREDIT', ylabel='AMT_GOODS_PRICE'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
loan_data = pd.DataFrame(np.random.rand(10, 10), columns=[f'var{i}' for i in range(10)])
correlation_matrix = loan_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(data=correlation_matrix, annot=True, linecolor='black', linewidths=0.6, fmt='.2f')
plt.show()

# %%
cat
# Out:
# ['TARGET',
#  'NAME_CONTRACT_TYPE',
#  'GENDER',
#  'Car',
#  'House',
#  'CNT_CHILDREN',
#  'NAME_TYPE_SUITE',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'MOBILE',
#  'WORK_PHONE',
#  'HOME_PHONE',
#  'MOBILE_REACHABLE',
#  'FLAG_EMAIL',
#  'CNT_FAM_MEMBERS',
#  'APPLICATION_DAY',
#  'TOTAL_DOC_SUBMITTED']

# %% [markdown]
# # Cat Vs Num

# %%
sns.boxplot(data=loan_data,x='TARGET',y='AMT_CREDIT')
# Out:
# <Axes: xlabel='TARGET', ylabel='AMT_CREDIT'>

# %%
sns.histplot(data=loan_data,x='TARGET',y='AMT_CREDIT')
# Out:
# <Axes: xlabel='TARGET', ylabel='AMT_CREDIT'>

# %%
#fig,ax=plt.subplots(1,2,figsize=(15,8))

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.lineplot(data=loan_data,x='NAME_EDUCATION_TYPE',y='AMT_CREDIT',ax=ax[0])
sns.barplot(data=loan_data,x='NAME_EDUCATION_TYPE',y='AMT_CREDIT',ax=ax[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Mutivariate Analysis

# %%
sns.pairplot(x)
# Out:
# C:\Users\Senthilkumar P\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
x=loan_data.loc[:,num]

# %%
x
# Out:
#        SK_ID_CURR  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  \
# 0          100002          202500.0    406597.5         351000.0
# 1          100003          270000.0   1293502.5        1129500.0
# 2          100004           67500.0    135000.0         135000.0
# 3          100006          135000.0    312682.5         297000.0
# 4          100007          121500.0    513000.0         513000.0
# ...           ...               ...         ...              ...
# 99995      216086          157500.0    755190.0         675000.0
# 99996      216087          225000.0    284400.0         225000.0
# 99997      216088          135000.0   1262583.0        1102500.0
# 99998      216089          135000.0    225000.0         225000.0
# 99999      216090          202500.0    337500.0         337500.0
#
#        DAYS_EMPLOYED OCCUPATION_TYPE
# 0               -637        Laborers
# 1              -1188      Core staff
# 2               -225        Laborers
# ...

# %%
def count_bar(ax):
    for bar in ax.patches:                                            
        percentage = f"{round(bar.get_height() , 2)}"  
                                                                   
        x = bar.get_x() + bar.get_width() /2                          
        y = bar.get_height()                                          
        ax.annotate(percentage, (x, y), va = "bottom", ha = "center")

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Difficulties in Paying loans vs Family ") 
sns.countplot(data=loan_data,hue='TARGET',x='NAME_FAMILY_STATUS',ax=ax[0])
count_bar(ax[0])
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize = (15, 7))
ax.set_title(" ") 
sns.countplot(data=loan_data,hue='TARGET',x='CNT_FAM_MEMBERS',ax=ax)
count_bar(ax)
plt.tight_layout()

# %%
cat and num
# Out:
# ['SK_ID_CURR',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_GOODS_PRICE',
#  'DAYS_EMPLOYED',
#  'OCCUPATION_TYPE']

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.lineplot(data=loan_data,x='GENDER',y='AMT_CREDIT',ax=ax[0],ci=99)
sns.barplot(data=loan_data,x='GENDER',y='AMT_CREDIT',ax=ax[1])
# Out:
# C:\Users\Senthilkumar P\AppData\Local\Temp\ipykernel_14460\2429614412.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 99)` for the same effect.
#
#   sns.lineplot(data=loan_data,x='GENDER',y='AMT_CREDIT',ax=ax[0],ci=99)
# <Axes: xlabel='GENDER', ylabel='AMT_CREDIT'>

# %%
def count_bar(ax):
    for bar in ax.patches:                                            
        percentage = f"{round(bar.get_height()/loan_data.shape[0]*100,2)}%"  
                                                                   
        x = bar.get_x() + bar.get_width() /2                          
        y = bar.get_height()                                          
        ax.annotate(percentage, (x, y), va = "bottom", ha = "center")

# %%
fig,ax=plt.subplots(figsize=(10,7))
sns.countplot(x=loan_data['GENDER'])
count_bar(ax)

# %%
EDA:
    L0:pandas function,head,tail.desc,info,isnull,dupl
    L1:univariant:cat(countplot,pie) or num(hist,box)
    L2:bivariant:cat-cat(bar,box,count),cat-num(box,bar),num-num(hist,scatter,heat)
    L3:multivariant:pairplt,headmap,bar,count
